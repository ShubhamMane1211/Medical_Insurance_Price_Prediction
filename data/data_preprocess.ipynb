# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("insurance.csv")
# Out:
# Running cells with '.venv (3.10.2) (Python 3.10.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"d:/NEW/complete python/Projects/Med_Insurance_Price_Prediction/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
